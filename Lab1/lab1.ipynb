# %% [markdown]
# <a href="https://colab.research.google.com/github/InnaK342/nn2022/blob/main/Lab1/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello

# %% [markdown]
# # Новий розділ
